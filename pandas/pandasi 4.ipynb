# %% [markdown]
# <div style="direction:ltl;line-height:100%;"><font face="B Nazanin" size=4>
# <font color=#007E06 size=3>
#     <h1>subset of dataset</h1>
# </font>
#
# <font size=4 >
#
#
#  </font>
#  </div>

# %%
import pandas as  pd

# %%
titanic = pd.read_csv("titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic["Age"].shape
# Out:
# (891,)

# %%
type(titanic["Age"])
# Out:
# pandas.core.series.Series

# %%
#show 2 col
titanic[["Age","Fare"]]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
type(titanic[["Age","Fare"]])
# Out:
# pandas.core.frame.DataFrame

# %%
above= titanic[titanic["Age"]>60]
above
# ages > 35 from titanic
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
titanic[(titanic["Pclass"]== 2 )| (titanic["Pclass"]== 3 )]
#{titanic[(titanic["Pclass"]== 2 )| (titanic["Pclass"]== 3 )] } =={ titanic[titanic["Pclass"].isin([2,3])]}
# who is Plclass=(2 or 3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic_ages_no_nan = titanic[titanic["Age"].notna()]
titanic_ages_no_nan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
adult_Names = titanic.loc[titanic["Age"]>60,"Name"]
adult_Names
# name of people that older than 60 years old
# Out:
# 33                         Wheadon, Mr. Edward H
# 54                Ostby, Mr. Engelhart Cornelius
# 96                     Goldschmidt, Mr. George B
# 116                         Connors, Mr. Patrick
# 170                    Van der hoef, Mr. Wyckoff
# 252                    Stead, Mr. William Thomas
# 275            Andrews, Miss. Kornelia Theodosia
# 280                             Duane, Mr. Frank
# 326                    Nysveen, Mr. Johan Hansen
# 438                            Fortune, Mr. Mark
# 456                    Millet, Mr. Francis Davis
# 483                       Turkula, Mrs. (Hedwig)
# 493                      Artagaveytia, Mr. Ramon
# 545                 Nicholson, Mr. Arthur Ernest
# 555                           Wright, Mr. George
# 570                           Harris, Mr. George
# 625                        Sutton, Mr. Frederick
# 630         Barkworth, Mr. Algernon Henry Wilson
# 672                  Mitchell, Mr. Henry Michael
# ...

# %%
adult_Names.index
# Out:
# Index([ 33,  54,  96, 116, 170, 252, 275, 280, 326, 438, 456, 483, 493, 545,
#        555, 570, 625, 630, 672, 745, 829, 851],
#       dtype='int64')

# %%
#Rows of 10 to 25 and cols from 3 to 5
newtitan = titanic.iloc[9:26 , 2:6]# [Rows , Columns]
newtitan
# Out:
#     Pclass                                               Name     Sex   Age
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10       3                    Sandstrom, Miss. Marguerite Rut  female   4.0
# 11       1                           Bonnell, Miss. Elizabeth  female  58.0
# 12       3                     Saundercock, Mr. William Henry    male  20.0
# 13       3                        Andersson, Mr. Anders Johan    male  39.0
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16       3                               Rice, Master. Eugene    male   2.0
# 17       2                       Williams, Mr. Charles Eugene    male   NaN
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 19       3                            Masselmani, Mrs. Fatima  female   NaN
# ...

# %%
#insert value to specefic row(s) & col(s)
titanic.iloc[0:3,10] = "C-payam"
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.iloc[0:10,0:12]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic["new Fare"] = titanic["Fare"] * titanic["Age"]
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#rename columns
titanic_reNamed = titanic.rename(
    columns={
        "Cabin" : "Otagh"
    }
)
titanic_reNamed
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic["new Fare"].mean()
# Out:
# np.float64(1104.1420529607844)

# %%
titanic[["new Fare","Fare"]].median()
# Out:
# new Fare    378.5000
# Fare         14.4542
# dtype: float64

# %%
titanic[["new Fare","Fare"]].describe()
# Out:
#            new Fare        Fare
# count    714.000000  891.000000
# mean    1104.142053   32.204208
# std     1949.356185   49.693429
# min        0.000000    0.000000
# 25%      203.906250    7.910400
# 50%      378.500000   14.454200
# 75%     1194.243750   31.000000
# max    18443.851200  512.329200

# %%
#ststistical summary
t1 = titanic.agg(
    {
        'Age' : ['min','max','median'],
        'Fare' :  ['min','max','median']
    }
)
t1
# Out:
#           Age      Fare
# min      0.42    0.0000
# max     80.00  512.3292
# median  28.00   14.4542

# %% [markdown]
# <div style="direction:ltl;line-height:100%;"><font face="B Nazanin" size=4>
# <font color=#007E06 size=3>
#
# </font>
#
# <font size=3 >
#
#     same code:
#     [titanic[["Sex","Age"]].groupby('Sex').mean()] == [titanic.groupby("Sex")['Age'].mean()]
#
#  </font>
#  </div>

# %%
titanic[["Sex","Age"]].groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby("Sex")['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic.groupby("Sex")['Age']

# %%
#number of passeger in each Pclass
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# <div style="direction:ltl;line-height:100%;"><font face="B Nazanin" size=4>
# <font color=#007E06 size=3>
#
# </font>
#
# <font size=3 >
#
#     same code:
#     titanic.groupby("Pclass")["Pclass"].count() == titanic.groupby("Pclass")["Pclass"].size()
#
# Size : nan ها را می شمارد
#
# Count : nan ها را نمی شمارد
#  </font>
#  </div>

# %%
titanic.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
titanic.groupby("Pclass")["Pclass"].size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
titanic.sort_values(by=["new Fare","Pclass"]).head()
#head یعنی 5 تا سطر اول
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 263          264         0       1            Harrison, Mr. William  male
# 806          807         0       1           Andrews, Mr. Thomas Jr  male
# 822          823         0       1  Reuchlin, Jonkheer. John George  male
# 179          180         0       3              Leonard, Mr. Lionel  male
# 271          272         1       3     Tornquist, Mr. William Henry  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked  new Fare
# 263  40.0      0      0  112059   0.0   B94        S       0.0
# 806  39.0      0      0  112050   0.0   A36        S       0.0
# 822  38.0      0      0   19972   0.0   NaN        S       0.0
# 179  36.0      0      0    LINE   0.0   NaN        S       0.0
# 271  25.0      0      0    LINE   0.0   NaN        S       0.0

# %%
titanic.sort_values(by=["new Fare","Pclass"] ,ascending= False)
#ascending = صعودی
# Out:
#      PassengerId  Survived  Pclass  \
# 679          680         1       1
# 258          259         1       1
# 737          738         1       1
# 438          439         0       1
# 299          300         1       1
# ..           ...       ...     ...
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
# 839          840         1       1
# 849          850         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 679               Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 258                                 Ward, Miss. Anna  female  35.0      0
# 737                           Lesurer, Mr. Gustave J    male  35.0      0
# 438                                Fortune, Mr. Mark    male  64.0      1
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# ..                                               ...     ...   ...    ...
# ...
