# %% [markdown]
# <h1>reshape the layout Tables </h1>

# %%
import pandas as pd

# %%
Aq = pd.read_csv("Air_Quality.csv")
Aq
# Out:
#        Unique ID  Indicator ID                                   Name  \
# 0         179772           640  Boiler Emissions- Total SO2 Emissions
# 1         179785           640  Boiler Emissions- Total SO2 Emissions
# 2         178540           365                Fine particles (PM 2.5)
# 3         178561           365                Fine particles (PM 2.5)
# 4         823217           365                Fine particles (PM 2.5)
# ...          ...           ...                                    ...
# 18020     816914           643          Annual vehicle miles traveled
# 18021     816913           643          Annual vehicle miles traveled
# 18022     816872           643          Annual vehicle miles traveled
# 18023     816832           643          Annual vehicle miles traveled
# 18024     151658           643          Annual vehicle miles traveled
#
#               Measure     Measure Info Geo Type Name  Geo Join ID  \
# ...

# %%
no2_sub = Aq[Aq['Name'] == "Nitrogen dioxide (NO2)"]
no2_sub
# Out:
#        Unique ID  Indicator ID                    Name Measure Measure Info  \
# 26        176692           375  Nitrogen dioxide (NO2)    Mean          ppb
# 27        549806           375  Nitrogen dioxide (NO2)    Mean          ppb
# 28        175369           375  Nitrogen dioxide (NO2)    Mean          ppb
# 29        175915           375  Nitrogen dioxide (NO2)    Mean          ppb
# 30        549872           375  Nitrogen dioxide (NO2)    Mean          ppb
# ...          ...           ...                     ...     ...          ...
# 17980     825908           375  Nitrogen dioxide (NO2)    Mean          ppb
# 17981     602875           375  Nitrogen dioxide (NO2)    Mean          ppb
# 17982     171581           375  Nitrogen dioxide (NO2)    Mean          ppb
# 17983     602890           375  Nitrogen dioxide (NO2)    Mean          ppb
# 17984     643504           375  Nitrogen dioxide (NO2)    Mean          ppb
#
# ...

# %%
no2_place = no2_sub.sort_index().groupby(["Geo Place Name"]).head(2)
# یعنی از هر گروه 2 تا مقدار اولشو که گروه بندی کردی به من بده
no2_place
# Out:
#        Unique ID  Indicator ID                    Name Measure Measure Info  \
# 26        176692           375  Nitrogen dioxide (NO2)    Mean          ppb
# 27        549806           375  Nitrogen dioxide (NO2)    Mean          ppb
# 28        175369           375  Nitrogen dioxide (NO2)    Mean          ppb
# 29        175915           375  Nitrogen dioxide (NO2)    Mean          ppb
# 30        549872           375  Nitrogen dioxide (NO2)    Mean          ppb
# ...          ...           ...                     ...     ...          ...
# 12908     171654           375  Nitrogen dioxide (NO2)    Mean          ppb
# 14776     549988           375  Nitrogen dioxide (NO2)    Mean          ppb
# 14777     602931           375  Nitrogen dioxide (NO2)    Mean          ppb
# 16637     643532           375  Nitrogen dioxide (NO2)    Mean          ppb
# 16638     667484           375  Nitrogen dioxide (NO2)    Mean          ppb
#
# ...

# %% [markdown]
# <h1 font = 'arial'>pivot , pivot table , melt for reshaping</h1>

# %%
Name_dataValue=no2_sub.sort_index().pivot(columns= "Name",
                                           values='Data Value' ).plot()
Name_dataValue
# Out:
# <Axes: >

# %%
place_dataValue=no2_sub.sort_index().pivot(columns= "Geo Place Name",
                                           values='Data Value' ).plot()
place_dataValue
# Out:
# <Axes: >

# %%
aq0 = Aq.pivot_table(
    values= 'Data Value' ,
    index= "Geo Place Name" ,
    columns= 'Name',
    aggfunc='mean' ,
    margins= True
)
aq0
# Out:
# Name                                  Annual vehicle miles traveled  \
# Geo Place Name
# Bay Ridge and Dyker Heights (CD10)                        70.866667
# Bayside - Little Neck                                     75.466667
# Bayside Little Neck-Fresh Meadows                               NaN
# Bayside and Little Neck (CD11)                            71.166667
# Bedford Stuyvesant (CD3)                                  64.766667
# ...                                                             ...
# Williamsbridge and Baychester (CD12)                      48.866667
# Williamsburg - Bushwick                                   44.566667
# Willowbrook                                               30.566667
# Woodside and Sunnyside (CD2)                             100.166667
# All                                                       73.430218
#
# Name                                  Annual vehicle miles traveled (cars)  \
# Geo Place Name
# ...
