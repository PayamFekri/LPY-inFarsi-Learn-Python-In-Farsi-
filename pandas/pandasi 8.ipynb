# %% [markdown]
# <font color = 'blue' size = 5>
#     <b>
#         manipulate textual data
#     </b>
# </font>

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic-string.csv")
titanic
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket     Fare
# 0           A/5 21171   7.2500
# 1            PC 17599  71.2833
# 2    STON/O2. 3101282   7.9250
# 3              113803  53.1000
# 4              373450   8.0500
# ...

# %%
titanic['Name'].str.lower() #lower case
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# <font face = 'XB Zar' color = 'black' size = 3>
#  </font>
#
#  <div style="direction:rtl;line-height:300%;"><font face="XB Zar" size=3>
#      خط پایین : یک ستون جدید ایجاد کردیم که نام های خانوادگی را در یک ستون مجزا قرار دهد
#
# get(0) : اولین بخش از سمت چپ رشته تا اولین کاما(,)
# </font></div>

# %%
titanic['LAST-NAME'] = titanic['Name'].str.split(',').str.get(0) 
titanic
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket     Fare  LAST-NAME
# 0           A/5 21171   7.2500     Braund
# 1            PC 17599  71.2833    Cumings
# 2    STON/O2. 3101282   7.9250  Heikkinen
# ...

# %%
edward_ = titanic['Name'].str.contains("Edward")
titanic[edward_]
# Out:
#                                                   Name     Sex         Ticket  \
# 33                               Wheadon, Mr. Edward H    male     C.A. 24579
# 245                        Minahan, Dr. William Edward    male          19928
# 283                         Dorking, Mr. Edward Arthur    male     A/5. 10482
# 332                          Graham, Mr. George Edward    male       PC 17582
# 487                            Kent, Mr. Edward Austin    male          11771
# 494                         Stanley, Mr. Edward Roland    male      A/4 45380
# 543                                  Beane, Mr. Edward    male           2908
# 546                  Beane, Mrs. Edward (Ethel Clarke)  female           2908
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female          11769
# 648                                 Willey, Mr. Edward    male  S.O./P.P. 751
# 662                         Colley, Mr. Edward Pomeroy    male           5727
# ...

# %% [markdown]
# <div style="direction:rtl;line-height:300%;"><font face="XB Zar" size=3>اون اسمی رو پیدا میکنه که از نظر طول بزرگترین باشه
# و بعد مشخصاتشو نمایش میده: پایین
# </font></div>

# %%
titanic.loc[titanic['Name'].str.len().idxmax()]
# Out:
# Name         Penasco y Castellana, Mrs. Victor de Satode (M...
# Sex                                                     female
# Ticket                                                PC 17758
# Fare                                                     108.9
# LAST-NAME                                 Penasco y Castellana
# Name: 307, dtype: object

# %%
titanic['short-gender'] = titanic['Sex'].replace({'male':'M','female':'F'})
titanic
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket     Fare  LAST-NAME short-gender
# 0           A/5 21171   7.2500     Braund            M
# 1            PC 17599  71.2833    Cumings            F
# ...
