# 118378  -0.040878  0.047556   0.079397 -0.050565  0.107052  0.139607
# 118379   0.015643  0.053693  -0.047626  0.090370 -0.042760 -0.027736
#
#         -0.412621  -0.469088
# 0       -0.568944  -0.477788
# 1       -0.046483  -0.705478
# 2       -0.320782  -0.735368
# 3       -0.050010  -0.341634
# 4       -0.339882  -0.378385
# ...           ...        ...
# 118375   0.013839   0.105910
# 118376   0.093915  -0.017583
# 118377  -0.006810  -0.037618
# 118378  -0.064489  -0.177276
# 118379   0.011910  -0.159299
#
# [118380 rows x 301 columns]

# %%
X = df.iloc[:, 1:].values
X
# Out:
# array([[-0.306765,  0.259314, -0.950335, ..., -0.219805, -0.568944,
#         -0.477788],
#        [-0.234556,  0.60916 , -0.065395, ...,  0.579194, -0.046483,
#         -0.705478],
#        [ 0.253033,  0.548086, -0.538728, ...,  0.40301 , -0.320782,
#         -0.735368],
#        ...,
#        [ 0.008636,  0.06761 , -0.133499, ...,  0.004968, -0.00681 ,
#         -0.037618],
#        [ 0.101569,  0.050567, -0.096631, ...,  0.139607, -0.064489,
#         -0.177276],
#        [-0.059097,  0.077194, -0.012921, ..., -0.027736,  0.01191 ,
#         -0.159299]], shape=(118380, 300))

# %%
from sklearn.cluster import KMeans,MeanShift, estimate_bandwidth , Birch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.metrics.pairwise import cosine_similarity

# %%
# محاسبه شباهت کسینوسی بین همه بردارها
similarity_matrix = cosine_similarity(X)
print("similarity_matrix:")
(similarity_matrix)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 # محاسبه شباهت کسینوسی بین همه بردارها
# ----> 2 similarity_matrix = cosine_similarity(X)
#       3 print("similarity_matrix:")
#       4 (similarity_matrix)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\pairwise.py:1736, in cosine_similarity(X, Y, dense_output)
#    1733 else:
#    1734     Y_normalized = normalize(Y, copy=True)
# -> 1736 K = safe_sparse_dot(X_normalized, Y_normalized.T, dense_output=dense_output)
#    1738 return K
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:203, in safe_sparse_dot(a, b, dense_output)
#     201         ret = xp.tensordot(a, b, axes=[-1, b_axis])
#     202 else:
# --> 203     ret = a @ b
#     205 if (
#     206     sparse.issparse(a)
#     207     and sparse.issparse(b)
#     208     and dense_output
#     209     and hasattr(ret, "toarray")
#     210 ):
#     211     return ret.toarray()
#
# MemoryError: Unable to allocate 104. GiB for an array with shape (118380, 118380) and data type float64

# %% [markdown]
# ### after-pca

# %%
x_new = pd.read_csv("after-pca.csv")
x_new
# Out:
#            rotoreuters        PC1       PC2        PC3       PC4       PC5  \
# 0             fiplefip  11.809120 -0.236315   9.712246 -3.558550  0.676302
# 1           amici_ursi  11.039474  0.714586   7.176633 -6.500434  1.621503
# 2          unremovable  12.308345  2.944823  13.467455 -6.039847 -1.338466
# 3              CDRE_64   9.597274 -0.275656   9.219146 -5.203834 -0.475436
# 4         noeatnosleep   8.441664 -1.520713   2.302667 -4.226753  1.043632
# ...                ...        ...       ...        ...       ...       ...
# 118375     rajkumareco  -1.599163 -2.210114  -0.625438  1.451997 -0.732024
# 118376       roryswife  -1.566509 -1.796675  -0.181276  0.900077 -0.054834
# 118377  shillagepeople  -1.464649 -0.546195  -0.242921  0.916454 -0.507969
# 118378         trizock  -3.842014  0.729138   0.563236 -0.146229 -1.710214
# 118379       zenlogick  -2.395113 -0.810977   1.138120  2.324378 -0.759313
#
#              PC6       PC7       PC8       PC9      PC10
# 0      -0.330307 -2.824460 -0.289928  0.484788 -3.428256
# 1       0.676836 -3.538689 -0.039432  2.002969  0.370842
# 2      -0.693709 -2.730207 -3.215488 -1.463924  0.722347
# 3       0.101921 -3.843878 -0.283923  1.681646  0.044997
# 4       1.490670 -6.036377  0.880610 -0.303432  0.104033
# ...          ...       ...       ...       ...       ...
# 118375  1.718785  0.016334 -1.454685 -0.107283 -0.624369
# 118376  0.360501  0.309659  0.537246 -0.411333  1.038730
# 118377  1.393093  0.776361 -0.526812 -0.956131  0.408481
# 118378 -0.352410 -0.227102 -0.158331 -1.738883 -1.016150
# 118379  1.013113  0.962529 -0.650111 -0.410960 -1.064653
#
# [118380 rows x 11 columns]

# %%
x_new = x_new.iloc[:, 1:].values
x_new
# Out:
# array([[11.80912037, -0.23631539,  9.71224592, ..., -0.28992769,
#          0.48478798, -3.42825628],
#        [11.03947443,  0.71458588,  7.17663344, ..., -0.03943228,
#          2.00296931,  0.37084166],
#        [12.3083445 ,  2.94482293, 13.46745475, ..., -3.21548813,
#         -1.46392375,  0.72234738],
#        ...,
#        [-1.46464946, -0.54619478, -0.24292068, ..., -0.5268124 ,
#         -0.95613134,  0.40848078],
#        [-3.84201432,  0.72913774,  0.56323623, ..., -0.15833144,
#         -1.73888332, -1.01614996],
#        [-2.39511271, -0.81097682,  1.13812011, ..., -0.65011088,
#         -0.41096005, -1.06465332]], shape=(118380, 10))

# %%
# محاسبه شباهت کسینوسی بین همه بردارها
similarity_matrix = cosine_similarity(x_new)
print("similarity_matrix:")
(similarity_matrix)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 # محاسبه شباهت کسینوسی بین همه بردارها
# ----> 2 similarity_matrix = cosine_similarity(x_new)
#       3 print("similarity_matrix:")
#       4 (similarity_matrix)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\pairwise.py:1736, in cosine_similarity(X, Y, dense_output)
#    1733 else:
#    1734     Y_normalized = normalize(Y, copy=True)
# -> 1736 K = safe_sparse_dot(X_normalized, Y_normalized.T, dense_output=dense_output)
#    1738 return K
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\extmath.py:203, in safe_sparse_dot(a, b, dense_output)
#     201         ret = xp.tensordot(a, b, axes=[-1, b_axis])
#     202 else:
# --> 203     ret = a @ b
#     205 if (
#     206     sparse.issparse(a)
#     207     and sparse.issparse(b)
#     208     and dense_output
#     209     and hasattr(ret, "toarray")
#     210 ):
#     211     return ret.toarray()
#
# MemoryError: Unable to allocate 104. GiB for an array with shape (118380, 118380) and data type float64
