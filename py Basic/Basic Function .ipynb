# %% [markdown]
# # Function

# %%
def f1():
    print('hi')
    a = 6
    b = 5
    c = a*b
    l  = ['l1' ,  'l2' , 3]
    return c , l
f1()
# Out:
# hi
# (30, ['l1', 'l2', 3])

# %%
def f2(a:int, b: int):
    x = a + b
    return f"{x} = {a} + {b}"

# %%
f2(12,4)
# Out:
# '16 = 12 + 4'

# %%
x = max (2,3,4,5,9,90,99,12,343, 345)
x
# Out:
# 345

# %%
code = {
    'a': '!',
    'b': 'v',
    'c': '6',
    'd': '(',
    'e': 'w',
    'f': '1',
    'g': ']',
    'h': 'A',
    'i': '=',
    'j': '?',
    'k': 'N',
    'l': '[',
    'm': '@',
    'n': '-',
    'o': '/',
    'p': '#',
    'q': '2',
    'r': '%',
    's': '*',
    't': '+',
    'u': '3',
    'v': 'r',
    'w': 'y',
    'x': '4',
    'y': '&',
    'z': ')',
    '.': 'U ',
    ' ': '_',
    'A': '2',
    '0' : '&9',
    '1': '*i',
    '2': '$!',
    '3': '.1/',
    '4': 'kl',
    '5': 'hj',
    '6': '56>',
    '7': '(?',
    '8': '^^',
    '9': '-ui,',
}

# %%
def EncodeInfo(name:str , id1 :int , number:None , password : str):
    pas  = ''
    id1  = str (id1)
    for j in code:
        for i in password:
            if i ==j :
                pas = pas + code[j]
        for k in id1:
            if k == j: 
                pas = pas + code[j]
        for n in name:
            if n == j :
                pas = pas + code[j]
    return pas

# %%
EncodeInfo('payam' , 12 ,912124, 'skfnvjksfn')
# Out:
# '!!11?NN@--#**r&*i$!'

# %%
def person(name = 'Payam' , age = 24 , last_name ='Fekri' ):
    return name , age , last_name
person()
# Out:
# ('Payam', 24, 'Fekri')

# %%
n , a , l = person(age = 30 , name = 'Ali')
n , a , l
# Out:
# ('Ali', 30, 'Fekri')

# %%
def f12(*args):
    for i in args:
        print(i)

# %%
f12(4,'payam' , 'gholi' , 34, [1,5,4 , 'L'])
# Out:
# 4
# payam
# gholi
# 34
# [1, 5, 4, 'L']

# %%
def FuncSum(*args : int):
    s = 0 
    for i in args:
        s = s + i
    return s

# %%
FuncSum(3,4,5,1)
# Out:
# 13

# %%
l = [3,2,4,6,10]
FuncSum(*l)
# Out:
# 25

# %%
def f3(**kwargs):
    return kwargs

# %%
f3(name = 'pppp' , age = 12 , id = 948294559)
# Out:
# {'name': 'pppp', 'age': 12, 'id': 948294559}

# %%
L9 = {
    "id" : 345801,
    'year' : 2012,
    'quality_fuel' : True

}
f3(**L9)
# Out:
# {'id': 345801, 'year': 2012, 'quality_fuel': True}

# %%
def f21(a, b, c, *args, default1 = "py", default2 = "C#", **kwargs):
    return a, b, c, args, default1, default2, kwargs

# %%
f21(a = 'payam' , b = 'pouya' , c = 'eric')
# Out:
# ('payam', 'pouya', 'eric', (), 'py', 'C#', {})

# %% [markdown]
# **kwargs create set
#
# *args create tuple and can get list
